# %% [markdown]
# # Instruction tuning with LoRA
#
# 1. Instruction tuning을 위한 데이터셋 만들기
#
# 2. LoRA로 모델에다 PEFT 하기
#
# 3. 훈련한 모델 허깅페이스 업로드

# %% [markdown]
# ## 1. Instruction tuning을 위한 데이터셋 만들기

# %%
# !pip -q install openai

# %%
import requests
from bs4 import BeautifulSoup
from google.colab import userdata
from openai import OpenAI
import csv
import os
import yaml
import re
import time
from tqdm import tqdm

# %%
champions = [
    "aatrox", "ahri", "akali", "akshan", "alistar", "amumu", "anivia", "annie", "aphelios", "ashe",
    "aurelionsol", "azir", "bard", "belveth", "blitzcrank", "brand", "braum", "caitlyn", "camille",
    "cassiopeia", "chogath", "corki", "darius", "diana", "drmundo", "draven", "ekko", "elise",
    "evelynn", "ezreal", "fiddlesticks", "fiora", "fizz", "galio", "gangplank", "garen", "gnar",
    "gragas", "graves", "gwen", "hecarim", "heimerdinger", "illaoi", "irelia", "ivern", "janna",
    "jarvaniv", "jax", "jayce", "jhin", "jinx", "kaisa", "kalista", "karma", "karthus", "kassadin",
    "katarina", "kayle", "kayn", "kennen", "khazix", "kindred", "kled", "kogmaw", "leblanc", "leesin",
    "leona", "lillia", "lissandra", "lucian", "lulu", "lux", "malphite", "malzahar", "maokai",
    "masteryi", "milio", "missfortune", "mordekaiser", "morgana", "naafiri", "nami", "nasus",
    "nautilus", "neeko", "nidalee", "nilah", "nocturne", "nunu", "olaf", "orianna", "ornn",
    "pantheon", "poppy", "pyke", "qiyana", "quinn", "rakan", "rammus", "reksai", "rell", "renataglasc",
    "renekton", "rengar", "riven", "rumble", "ryze", "samira", "sejuani", "senna", "seraphine", "sett",
    "shaco", "shen", "shyvana", "singed", "sion", "sivir", "skarner", "sona", "soraka", "swain",
    "sylas", "syndra", "tahmkench", "taliyah", "talon", "taric", "teemo", "thresh", "tristana",
    "trundle", "tryndamere", "twistedfate", "twitch", "udyr", "urgot", "varus", "vayne", "veigar",
    "velkoz", "vex", "vi", "viego", "viktor", "vladimir", "volibear", "warwick", "monkeyking", "xayah",
    "xerath", "xinzhao", "yasuo", "yone", "yorick", "yuumi", "zac", "zed", "ziggs", "zilean", "zoe", "zyra"
]
print(len(champions))

base_url = "https://universe.leagueoflegends.com/ko_KR/story/champion/"

def scrape_champion_data(champion):
    url = base_url + champion + "/"
    try:
        response = requests.get(url)
    except requests.exceptions.RequestException as e:
        print(f"Error: An exception occurred while requesting data for '{champion}': {e}")
        return None, None

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        korean_name = soup.find('title').text.split('-')[0].strip()

        meta_description = soup.find('meta', {'name': 'description'})
        if meta_description:
            background_story = meta_description.get('content').replace('\n', ' ').strip()
        else:
            background_story = None
            print(f"Error: No background story found for champion '{champion}'.")

        return korean_name, background_story
    else:
        print(f"Error: Failed to fetch data for champion '{champion}'. HTTP status code: {response.status_code}")
        return None, None

with open("champion_bs.csv", "w", newline='', encoding='utf-8') as csvfile:
    fieldnames = ['url-name', 'korean-name', 'background-story']

    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    for champion in tqdm(champions, desc="Scraping champions"):
        korean_name, background_story = scrape_champion_data(champion)
        if korean_name and background_story:
            writer.writerow({
                'url-name': champion,
                'korean-name': korean_name,
                'background-story': background_story
            })
# Out:
# 162
# Scraping champions: 100%|██████████| 162/162 [00:51<00:00,  3.15it/s]

# %%
client = OpenAI(
    api_key=userdata.get('OPENAI_TOKEN')
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-4o-mini",
)

chat_completion.choices[0].message.content
# Out:
# 'This is a test. How can I assist you further?'

# %%
client = OpenAI(
    api_key=userdata.get('OPENAI_TOKEN')
)

base_prompt = """
위 글은 온라인 게임 리그 오브 레전드의 한 캐릭터의 배경 설명입니다.
이 캐릭터의 배경과 관련된 질문과 답변을 생성해 주세요.
다음 단계를 따라 주세요:

1. 생각하기 단계 (`<thinking>` 태그):
   - 생성할 질문과 답변에 대해 먼저 생각해 보세요.
   - 캐릭터의 핵심 정보, 중요한 사건, 행동 또는 결정과 그 결과에 관한 질문을 고려하세요.

2. 질문과 답변 작성 (`<qna>` 태그):
   - 질문은 짧고 명확하게 작성하세요.
   - 답변은 구체적이며 텍스트에서 직접적으로 추론할 수 있도록 작성하세요.
   - 아래 형식을 참고하여 질문과 답변을 작성하세요.

형식 예시:
<qna>
- q: "대부분의 필멸자가 알고 있는 현실 차원은 무엇인가?"
  a: "대부분의 필멸자는 물질 세계라는 하나의 현실 차원만 알고 있다."
- q: "오로라가 유년 시절을 보낸 곳은 어디인가?"
  a: "오로라는 브뤼니 부족의 고향이자 외딴 마을인 아무우에서 유년 시절을 보냈다."
- q: "오로라가 자신을 이해해준 유일한 가족 구성원은 누구인가?"
  a: "오로라의 이모할머니 하부우가 오로라를 진심으로 받아들였다."
- q: "오로라가 유년 시절에 보고 경험한 세계는 어떤 세계였나?"
  a: "오로라는 필멸 세계와 영혼 세계의 장막을 꿰뚫는 특별한 세계를 경험했다."
- q: "오로라는 무엇을 연구하며 기록했는가?"
  a: "오로라는 아무우의 영혼과 뒤얽힌 세계를 연구하며 세심하게 기록했다."
</qna>
"""

def generate_questions_and_answers(story):
    prompt = story + "\n\n" + base_prompt
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ],
        model="gpt-4o-mini",
    )
    return chat_completion.choices[0].message.content.strip()

def extract_qna(content):
    match = re.search(r"<qna>(.*?)</qna>", content, re.DOTALL)
    if match:
        return match.group(1).strip()
    return None

def parse_qna(qna_content):
    try:
        qa_list = yaml.safe_load(qna_content)
        if isinstance(qa_list, list) and all(isinstance(item, dict) for item in qa_list):
            qa_pairs = []
            for item in qa_list:
                if 'q' in item and 'a' in item:
                    qa_pairs.append((item['q'], item['a']))
                else:
                    raise ValueError("Each Q&A pair must contain 'q' and 'a' keys.")
            return qa_pairs
        else:
            raise ValueError("Q&A content is not a list of dictionaries.")
    except yaml.YAMLError as e:
        raise ValueError(f"YAML parsing error: {e}")

def write_qa_to_csv(qa_pairs):
    with open('champion_qa.csv', mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        for question, answer in qa_pairs:
            writer.writerow([question, answer])

def generate_qa_from_bs(file_path):
    successful_champions = 0
    with open(file_path, newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        champions = list(reader)
        total_champions = len(champions)
        for index, row in enumerate(champions, start=1):
            url_name = row['url-name']
            korean_name = row['korean-name']
            background_story = row['background-story']
            display_name = f"{korean_name} ({url_name})"
            print(f"Processing {display_name}...")
            attempts = 0
            while attempts < 3:
                try:
                    output = generate_questions_and_answers(background_story)
                    qna_content = extract_qna(output)
                    if not qna_content:
                        raise ValueError("No <qna> tags found in the response.")
                    qa_pairs = parse_qna(qna_content)
                    write_qa_to_csv(qa_pairs)
                    successful_champions += 1
                    print(f"Successfully wrote Q&A for {display_name} ({successful_champions}/{total_champions})")
                    break
                except Exception as e:
                    attempts += 1
                    print(f"Error processing {display_name}: {e}. Attempt {attempts}/3.")
                    if attempts < 3:
                        time.sleep(1)
                    else:
                        print(f"Failed to generate valid Q&A for {display_name} after 3 attempts.")
    print(f"\nTotal number of champions successfully processed: {successful_champions}")

with open('champion_qa.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["q", "a"])

generate_qa_from_bs('champion_bs.csv')
# Out:
# Processing 아트록스 (aatrox)...
# Successfully wrote Q&A for 아트록스 (aatrox) (1/162)
# Processing 아리 (ahri)...
# Successfully wrote Q&A for 아리 (ahri) (2/162)
# Processing 아칼리 (akali)...
# Successfully wrote Q&A for 아칼리 (akali) (3/162)
# Processing 아크샨 (akshan)...
# Successfully wrote Q&A for 아크샨 (akshan) (4/162)
# Processing 알리스타 (alistar)...
# Successfully wrote Q&A for 알리스타 (alistar) (5/162)
# Processing 아무무 (amumu)...
# Successfully wrote Q&A for 아무무 (amumu) (6/162)
# Processing 애니비아 (anivia)...
# Successfully wrote Q&A for 애니비아 (anivia) (7/162)
# Processing 애니 (annie)...
# Successfully wrote Q&A for 애니 (annie) (8/162)
# Processing 아펠리오스 (aphelios)...
# Successfully wrote Q&A for 아펠리오스 (aphelios) (9/162)
# Processing 애쉬 (ashe)...
# Successfully wrote Q&A for 애쉬 (ashe) (10/162)
# Processing 아우렐리온 솔 (aurelionsol)...
# Successfully wrote Q&A for 아우렐리온 솔 (aurelionsol) (11/162)
# Processing 아지르 (azir)...
# Successfully wrote Q&A for 아지르 (azir) (12/162)
# Processing 바드 (bard)...
# Successfully wrote Q&A for 바드 (bard) (13/162)
# Processing 벨베스 (belveth)...
# Successfully wrote Q&A for 벨베스 (belveth) (14/162)
# Processing 블리츠크랭크 (blitzcrank)...
# Successfully wrote Q&A for 블리츠크랭크 (blitzcrank) (15/162)
# Processing 브랜드 (brand)...
# Successfully wrote Q&A for 브랜드 (brand) (16/162)
# Processing 브라움 (braum)...
# Successfully wrote Q&A for 브라움 (braum) (17/162)
# Processing 케이틀린 (caitlyn)...
# Successfully wrote Q&A for 케이틀린 (caitlyn) (18/162)
# Processing 카밀 (camille)...
# Successfully wrote Q&A for 카밀 (camille) (19/162)
# Processing 카시오페아 (cassiopeia)...
# Successfully wrote Q&A for 카시오페아 (cassiopeia) (20/162)
# Processing 초가스 (chogath)...
# Successfully wrote Q&A for 초가스 (chogath) (21/162)
# Processing 코르키 (corki)...
# Successfully wrote Q&A for 코르키 (corki) (22/162)
# Processing 다리우스 (darius)...
# Successfully wrote Q&A for 다리우스 (darius) (23/162)
# Processing 다이애나 (diana)...
# Successfully wrote Q&A for 다이애나 (diana) (24/162)
# Processing 문도 박사 (drmundo)...
# Successfully wrote Q&A for 문도 박사 (drmundo) (25/162)
# Processing 드레이븐 (draven)...
# Successfully wrote Q&A for 드레이븐 (draven) (26/162)
# Processing 에코 (ekko)...
# Successfully wrote Q&A for 에코 (ekko) (27/162)
# Processing 엘리스 (elise)...
# Successfully wrote Q&A for 엘리스 (elise) (28/162)
# Processing 이블린 (evelynn)...
# Successfully wrote Q&A for 이블린 (evelynn) (29/162)
# Processing 이즈리얼 (ezreal)...
# Successfully wrote Q&A for 이즈리얼 (ezreal) (30/162)
# Processing 피들스틱 (fiddlesticks)...
# Successfully wrote Q&A for 피들스틱 (fiddlesticks) (31/162)
# Processing 피오라 (fiora)...
# Successfully wrote Q&A for 피오라 (fiora) (32/162)
# Processing 피즈 (fizz)...
# Successfully wrote Q&A for 피즈 (fizz) (33/162)
# Processing 갈리오 (galio)...
# Successfully wrote Q&A for 갈리오 (galio) (34/162)
# Processing 갱플랭크 (gangplank)...
# Successfully wrote Q&A for 갱플랭크 (gangplank) (35/162)
# Processing 가렌 (garen)...
# Successfully wrote Q&A for 가렌 (garen) (36/162)
# Processing 나르 (gnar)...
# Successfully wrote Q&A for 나르 (gnar) (37/162)
# Processing 그라가스 (gragas)...
# Successfully wrote Q&A for 그라가스 (gragas) (38/162)
# Processing 그레이브즈 (graves)...
# Successfully wrote Q&A for 그레이브즈 (graves) (39/162)
# Processing 그웬 (gwen)...
# Successfully wrote Q&A for 그웬 (gwen) (40/162)
# Processing 헤카림 (hecarim)...
# Successfully wrote Q&A for 헤카림 (hecarim) (41/162)
# Processing 하이머딩거 (heimerdinger)...
# Successfully wrote Q&A for 하이머딩거 (heimerdinger) (42/162)
# Processing 일라오이 (illaoi)...
# Successfully wrote Q&A for 일라오이 (illaoi) (43/162)
# Processing 이렐리아 (irelia)...
# Successfully wrote Q&A for 이렐리아 (irelia) (44/162)
# Processing 아이번 (ivern)...
# Successfully wrote Q&A for 아이번 (ivern) (45/162)
# Processing 잔나 (janna)...
# Successfully wrote Q&A for 잔나 (janna) (46/162)
# Processing 자르반 4세 (jarvaniv)...
# Successfully wrote Q&A for 자르반 4세 (jarvaniv) (47/162)
# Processing 잭스 (jax)...
# Successfully wrote Q&A for 잭스 (jax) (48/162)
# Processing 제이스 (jayce)...
# Successfully wrote Q&A for 제이스 (jayce) (49/162)
# Processing 진 (jhin)...
# Successfully wrote Q&A for 진 (jhin) (50/162)
# Processing 징크스 (jinx)...
# Successfully wrote Q&A for 징크스 (jinx) (51/162)
# Processing 카이사 (kaisa)...
# Successfully wrote Q&A for 카이사 (kaisa) (52/162)
# Processing 칼리스타 (kalista)...
# Successfully wrote Q&A for 칼리스타 (kalista) (53/162)
# Processing 카르마 (karma)...
# Successfully wrote Q&A for 카르마 (karma) (54/162)
# Processing 카서스 (karthus)...
# Successfully wrote Q&A for 카서스 (karthus) (55/162)
# Processing 카사딘 (kassadin)...
# Successfully wrote Q&A for 카사딘 (kassadin) (56/162)
# Processing 카타리나 (katarina)...
# Successfully wrote Q&A for 카타리나 (katarina) (57/162)
# Processing 케일 (kayle)...
# Successfully wrote Q&A for 케일 (kayle) (58/162)
# Processing 케인 (kayn)...
# Successfully wrote Q&A for 케인 (kayn) (59/162)
# Processing 케넨 (kennen)...
# Successfully wrote Q&A for 케넨 (kennen) (60/162)
# Processing 카직스 (khazix)...
# Successfully wrote Q&A for 카직스 (khazix) (61/162)
# Processing 킨드레드 (kindred)...
# Successfully wrote Q&A for 킨드레드 (kindred) (62/162)
# Processing 클레드 (kled)...
# Successfully wrote Q&A for 클레드 (kled) (63/162)
# Processing 코그모 (kogmaw)...
# Successfully wrote Q&A for 코그모 (kogmaw) (64/162)
# Processing 르블랑 (leblanc)...
# Successfully wrote Q&A for 르블랑 (leblanc) (65/162)
# Processing 리 신 (leesin)...
# Successfully wrote Q&A for 리 신 (leesin) (66/162)
# Processing 레오나 (leona)...
# Successfully wrote Q&A for 레오나 (leona) (67/162)
# Processing 릴리아 (lillia)...
# Successfully wrote Q&A for 릴리아 (lillia) (68/162)
# Processing 리산드라 (lissandra)...
# Successfully wrote Q&A for 리산드라 (lissandra) (69/162)
# Processing 루시안 (lucian)...
# Successfully wrote Q&A for 루시안 (lucian) (70/162)
# Processing 룰루 (lulu)...
# Successfully wrote Q&A for 룰루 (lulu) (71/162)
# Processing 럭스 (lux)...
# Successfully wrote Q&A for 럭스 (lux) (72/162)
# Processing 말파이트 (malphite)...
# Successfully wrote Q&A for 말파이트 (malphite) (73/162)
# Processing 말자하 (malzahar)...
# Successfully wrote Q&A for 말자하 (malzahar) (74/162)
# Processing 마오카이 (maokai)...
# Successfully wrote Q&A for 마오카이 (maokai) (75/162)
# Processing 마스터 이 (masteryi)...
# Successfully wrote Q&A for 마스터 이 (masteryi) (76/162)
# Processing 밀리오 (milio)...
# Successfully wrote Q&A for 밀리오 (milio) (77/162)
# Processing 미스 포츈 (missfortune)...
# Successfully wrote Q&A for 미스 포츈 (missfortune) (78/162)
# Processing 모데카이저 (mordekaiser)...
# Successfully wrote Q&A for 모데카이저 (mordekaiser) (79/162)
# Processing 모르가나 (morgana)...
# Successfully wrote Q&A for 모르가나 (morgana) (80/162)
# Processing 나피리 (naafiri)...
# Successfully wrote Q&A for 나피리 (naafiri) (81/162)
# Processing 나미 (nami)...
# Successfully wrote Q&A for 나미 (nami) (82/162)
# Processing 나서스 (nasus)...
# Successfully wrote Q&A for 나서스 (nasus) (83/162)
# Processing 노틸러스 (nautilus)...
# Successfully wrote Q&A for 노틸러스 (nautilus) (84/162)
# Processing 니코 (neeko)...
# Successfully wrote Q&A for 니코 (neeko) (85/162)
# Processing 니달리 (nidalee)...
# Successfully wrote Q&A for 니달리 (nidalee) (86/162)
# Processing 닐라 (nilah)...
# Successfully wrote Q&A for 닐라 (nilah) (87/162)
# Processing 녹턴 (nocturne)...
# Successfully wrote Q&A for 녹턴 (nocturne) (88/162)
# Processing 누누와 윌럼프 (nunu)...
# Successfully wrote Q&A for 누누와 윌럼프 (nunu) (89/162)
# Processing 올라프 (olaf)...
# Successfully wrote Q&A for 올라프 (olaf) (90/162)
# Processing 오리아나 (orianna)...
# Successfully wrote Q&A for 오리아나 (orianna) (91/162)
# Processing 오른 (ornn)...
# Successfully wrote Q&A for 오른 (ornn) (92/162)
# Processing 판테온 (pantheon)...
# Successfully wrote Q&A for 판테온 (pantheon) (93/162)
# Processing 뽀삐 (poppy)...
# Successfully wrote Q&A for 뽀삐 (poppy) (94/162)
# Processing 파이크 (pyke)...
# Successfully wrote Q&A for 파이크 (pyke) (95/162)
# Processing 키아나 (qiyana)...
# Successfully wrote Q&A for 키아나 (qiyana) (96/162)
# Processing 퀸 (quinn)...
# Successfully wrote Q&A for 퀸 (quinn) (97/162)
# Processing 라칸 (rakan)...
# Successfully wrote Q&A for 라칸 (rakan) (98/162)
# Processing 람머스 (rammus)...
# Successfully wrote Q&A for 람머스 (rammus) (99/162)
# Processing 렉사이 (reksai)...
# Successfully wrote Q&A for 렉사이 (reksai) (100/162)
# Processing 렐 (rell)...
# Successfully wrote Q&A for 렐 (rell) (101/162)
# Processing 레나타 글라스크 (renataglasc)...
# Successfully wrote Q&A for 레나타 글라스크 (renataglasc) (102/162)
# Processing 레넥톤 (renekton)...
# Successfully wrote Q&A for 레넥톤 (renekton) (103/162)
# Processing 렝가 (rengar)...
# Successfully wrote Q&A for 렝가 (rengar) (104/162)
# Processing 리븐 (riven)...
# Successfully wrote Q&A for 리븐 (riven) (105/162)
# Processing 럼블 (rumble)...
# Successfully wrote Q&A for 럼블 (rumble) (106/162)
# Processing 라이즈 (ryze)...
# Successfully wrote Q&A for 라이즈 (ryze) (107/162)
# Processing 사미라 (samira)...
# Successfully wrote Q&A for 사미라 (samira) (108/162)
# Processing 세주아니 (sejuani)...
# Successfully wrote Q&A for 세주아니 (sejuani) (109/162)
# Processing 세나 (senna)...
# Successfully wrote Q&A for 세나 (senna) (110/162)
# Processing 세라핀 (seraphine)...
# Successfully wrote Q&A for 세라핀 (seraphine) (111/162)
# Processing 세트 (sett)...
# Successfully wrote Q&A for 세트 (sett) (112/162)
# Processing 샤코 (shaco)...
# Successfully wrote Q&A for 샤코 (shaco) (113/162)
# Processing 쉔 (shen)...
# Successfully wrote Q&A for 쉔 (shen) (114/162)
# Processing 쉬바나 (shyvana)...
# Successfully wrote Q&A for 쉬바나 (shyvana) (115/162)
# Processing 신지드 (singed)...
# Successfully wrote Q&A for 신지드 (singed) (116/162)
# Processing 사이온 (sion)...
# Successfully wrote Q&A for 사이온 (sion) (117/162)
# Processing 시비르 (sivir)...
# Successfully wrote Q&A for 시비르 (sivir) (118/162)
# Processing 스카너 (skarner)...
# Successfully wrote Q&A for 스카너 (skarner) (119/162)
# Processing 소나 (sona)...
# Successfully wrote Q&A for 소나 (sona) (120/162)
# Processing 소라카 (soraka)...
# Successfully wrote Q&A for 소라카 (soraka) (121/162)
# Processing 스웨인 (swain)...
# Successfully wrote Q&A for 스웨인 (swain) (122/162)
# Processing 사일러스 (sylas)...
# Successfully wrote Q&A for 사일러스 (sylas) (123/162)
# Processing 신드라 (syndra)...
# Successfully wrote Q&A for 신드라 (syndra) (124/162)
# Processing 탐 켄치 (tahmkench)...
# Successfully wrote Q&A for 탐 켄치 (tahmkench) (125/162)
# Processing 탈리야 (taliyah)...
# Successfully wrote Q&A for 탈리야 (taliyah) (126/162)
# Processing 탈론 (talon)...
# Successfully wrote Q&A for 탈론 (talon) (127/162)
# Processing 타릭 (taric)...
# Successfully wrote Q&A for 타릭 (taric) (128/162)
# Processing 티모 (teemo)...
# Successfully wrote Q&A for 티모 (teemo) (129/162)
# Processing 쓰레쉬 (thresh)...
# Successfully wrote Q&A for 쓰레쉬 (thresh) (130/162)
# Processing 트리스타나 (tristana)...
# Successfully wrote Q&A for 트리스타나 (tristana) (131/162)
# Processing 트런들 (trundle)...
# Successfully wrote Q&A for 트런들 (trundle) (132/162)
# Processing 트린다미어 (tryndamere)...
# Successfully wrote Q&A for 트린다미어 (tryndamere) (133/162)
# Processing 트위스티드 페이트 (twistedfate)...
# Successfully wrote Q&A for 트위스티드 페이트 (twistedfate) (134/162)
# Processing 트위치 (twitch)...
# Successfully wrote Q&A for 트위치 (twitch) (135/162)
# Processing 우디르 (udyr)...
# Successfully wrote Q&A for 우디르 (udyr) (136/162)
# Processing 우르곳 (urgot)...
# Successfully wrote Q&A for 우르곳 (urgot) (137/162)
# Processing 바루스 (varus)...
# Successfully wrote Q&A for 바루스 (varus) (138/162)
# Processing 베인 (vayne)...
# Successfully wrote Q&A for 베인 (vayne) (139/162)
# Processing 베이가 (veigar)...
# Successfully wrote Q&A for 베이가 (veigar) (140/162)
# Processing 벨코즈 (velkoz)...
# Successfully wrote Q&A for 벨코즈 (velkoz) (141/162)
# Processing 벡스 (vex)...
# Successfully wrote Q&A for 벡스 (vex) (142/162)
# Processing 바이 (vi)...
# Successfully wrote Q&A for 바이 (vi) (143/162)
# Processing 비에고 (viego)...
# Successfully wrote Q&A for 비에고 (viego) (144/162)
# Processing 빅토르 (viktor)...
# Successfully wrote Q&A for 빅토르 (viktor) (145/162)
# Processing 블라디미르 (vladimir)...
# Successfully wrote Q&A for 블라디미르 (vladimir) (146/162)
# Processing 볼리베어 (volibear)...
# Successfully wrote Q&A for 볼리베어 (volibear) (147/162)
# Processing 워윅 (warwick)...
# Successfully wrote Q&A for 워윅 (warwick) (148/162)
# Processing 오공 (monkeyking)...
# Successfully wrote Q&A for 오공 (monkeyking) (149/162)
# Processing 자야 (xayah)...
# Successfully wrote Q&A for 자야 (xayah) (150/162)
# Processing 제라스 (xerath)...
# Successfully wrote Q&A for 제라스 (xerath) (151/162)
# Processing 신 짜오 (xinzhao)...
# Successfully wrote Q&A for 신 짜오 (xinzhao) (152/162)
# Processing 야스오 (yasuo)...
# Successfully wrote Q&A for 야스오 (yasuo) (153/162)
# Processing 요네 (yone)...
# Successfully wrote Q&A for 요네 (yone) (154/162)
# Processing 요릭 (yorick)...
# Successfully wrote Q&A for 요릭 (yorick) (155/162)
# Processing 유미 (yuumi)...
# Successfully wrote Q&A for 유미 (yuumi) (156/162)
# Processing 자크 (zac)...
# Successfully wrote Q&A for 자크 (zac) (157/162)
# Processing 제드 (zed)...
# Successfully wrote Q&A for 제드 (zed) (158/162)
# Processing 직스 (ziggs)...
# Successfully wrote Q&A for 직스 (ziggs) (159/162)
# Processing 질리언 (zilean)...
# Successfully wrote Q&A for 질리언 (zilean) (160/162)
# Processing 조이 (zoe)...
# Successfully wrote Q&A for 조이 (zoe) (161/162)
# Processing 자이라 (zyra)...
# Successfully wrote Q&A for 자이라 (zyra) (162/162)
#
# Total number of champions successfully processed: 162

# %%
from google.colab import files

files.download('champion_qa.csv')

# %% [markdown]
# ## 2. LoRA로 모델에다 PEFT 하기

# %%
# !pip -q install datasets peft trl bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.9/310.9 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import os
import torch
import pandas as pd
from datasets import Dataset, load_from_disk
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
from peft import LoraConfig, get_peft_model
from trl import SFTTrainer, setup_chat_format
import bitsandbytes as bnb
from google.colab import userdata
from huggingface_hub import login

login(userdata.get('HF_TOKEN'))

# %%
BASE_MODEL = "google/gemma-2-2b-it"
OUTPUT_MODEL_PATH = "./gemma-2-2b-it-lol"

# %%
df = pd.read_csv("champion_qa.csv")
df.head()
# Out:
#                                  q  \
# 0  아트록스는 어떤 존재였으며, 처음에 어떤 역할을 했는가?
# 1      아트록스가 다르킨으로 불리게 된 이유는 무엇인가?
# 2      아트록스가 공허와의 전투에서 잃은 것은 무엇인가?
# 3    아트록스는 어떻게 그의 검에 영원히 갇히게 되었는가?
# 4               현재 아트록스의 목표는 무엇인가?
#
#                                                    a
# 0  아트록스는 슈리마의 용맹한 전사로서 태양 원판의 화신이며, 고귀한 전투의 선두에서 ...
# 1  공허의 위협 이후, 아트록스와 그의 동료 초월체들이 타락하면서 필멸자들이 그들을 경...
# 2  아트록스와 그의 동족은 공허와의 전투에서 영원한 변화를 겪었으며, 고귀했던 본질과 ...
# 3  타곤의 여명의 성위가 가르친 수단에 따라 필멸자들이 아트록스를 속이고 그의 힘을 검...
# 4  아트록스는 자신의 절망과 고통을 끝내기 위해 완전한 파멸을 받아들이고, 이를 통해 ...

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %%
dataset = Dataset.from_pandas(df)

def format_chat_prompt(record):
    chat_data = [
        {"role": "user", "content": record["q"]},
        {"role": "assistant", "content": record["a"]}
    ]
    record["qna"] = tokenizer.apply_chat_template(chat_data, tokenize=False)
    return record

dataset = dataset.map(format_chat_prompt, num_proc=4)
print(len(dataset))
# Out:
# Map (num_proc=4):   0%|          | 0/1239 [00:00<?, ? examples/s]
# 1239

# %%
dataset[523]
# Out:
# {'q': '루시안이 어릴 때부터 품었던 소망은 무엇인가?',
#  'a': '루시안은 아버지 유리아스처럼 빛의 감시단에 들어가는 것이 소망이었다.',
#  'qna': '<bos><start_of_turn>user\n루시안이 어릴 때부터 품었던 소망은 무엇인가?<end_of_turn>\n<start_of_turn>model\n루시안은 아버지 유리아스처럼 빛의 감시단에 들어가는 것이 소망이었다.<end_of_turn>\n'}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
torch_dtype = torch.float16
attn_implementation = "eager"

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch_dtype,
    bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quantization_config,
    device_map="auto",
    attn_implementation=attn_implementation
)
# Out:
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]

# %%
def generate_response(prompt, model, tokenizer, temperature=0.1):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=temperature > 0,
        temperature=temperature
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=False)

test_prompt = """<start_of_turn>user
"다리우스에게 '녹서스의 실력자'라는 칭호를 준 사람은?<end_of_turn>
<start_of_turn>model
"""
response = generate_response(test_prompt, model, tokenizer)
print(response)

test_prompt = """<start_of_turn>user
"이즈리얼 부모님의 어떤 직업은?<end_of_turn>
<start_of_turn>model
"""
response = generate_response(test_prompt, model, tokenizer)
print(response)

test_prompt = """<start_of_turn>user
"신지드는 왜 자운으로 이주했나?<end_of_turn>
<start_of_turn>model
"""
response = generate_response(test_prompt, model, tokenizer)
print(response)
# Out:
# <bos><start_of_turn>user
# "다리우스에게 '녹서스의 실력자'라는 칭호를 준 사람은?<end_of_turn>
# <start_of_turn>model
#  다리우스에게 '녹서스의 실력자'라는 칭호를 준 사람은 **'녹서스'**입니다.
#
# 다리우스는 녹서스의 실력을 인정하고, 그를 '녹서스의 실력자'라고 부르는 것을 칭찬하는 듯 합니다.
#
# 이 칭호는 녹서스의 뛰어난 능력과 다리우스의 존경을 보여주는 듯 합니다.
# <end_of_turn>
# <bos><start_of_turn>user
# "이즈리얼 부모님의 어떤 직업은?<end_of_turn>
# <start_of_turn>model
# 죄송하지만, 저는 이즈리얼 부모님의 직업에 대한 정보를 가지고 있지 않습니다.
#
# 저는 인공지능 모델이기 때문에 개인 정보에 접근할 수 없으며, 특정 사람들의 정보를 제공할 수 없습니다.
#
# 이즈리얼 부모님의 직업에 대해 더 자세히 알고 싶다면, 직접 이즈리얼에게 물어보는 것이 가장 좋습니다. 😊
# <end_of_turn>
# <bos><start_of_turn>user
# "신지드는 왜 자운으로 이주했나?<end_of_turn>
# <start_of_turn>model
# 죄송하지만, 답변을 드릴 수 없습니다.
#
# "신지드는 왜 자운으로 이주했나?"라는 질문은 좀 더 구체적인 정보가 필요합니다.
#
# * **신지드**는 누구인가요?
# * **자운**은 어떤 의미인가요?
#
# 질문에 대한 답변을 드릴 수 있도록 더 자세한 정보를 제공해주시면 감사하겠습니다.
# <end_of_turn>

# %%
model
# Out:
# Gemma2ForCausalLM(
#   (model): Gemma2Model(
#     (embed_tokens): Embedding(256000, 2304, padding_idx=0)
#     (layers): ModuleList(
#       (0-25): 26 x Gemma2DecoderLayer(
#         (self_attn): Gemma2Attention(
#           (q_proj): Linear4bit(in_features=2304, out_features=2048, bias=False)
#           (k_proj): Linear4bit(in_features=2304, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=2304, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=2048, out_features=2304, bias=False)
#           (rotary_emb): Gemma2RotaryEmbedding()
#         )
#         (mlp): Gemma2MLP(
#           (gate_proj): Linear4bit(in_features=2304, out_features=9216, bias=False)
#           (up_proj): Linear4bit(in_features=2304, out_features=9216, bias=False)
#           (down_proj): Linear4bit(in_features=9216, out_features=2304, bias=False)
#           (act_fn): PytorchGELUTanh()
#         )
#         (input_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#         (pre_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#         (post_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#         (post_attention_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#       )
#     )
#     (norm): Gemma2RMSNorm((2304,), eps=1e-06)
#   )
#   (lm_head): Linear(in_features=2304, out_features=256000, bias=False)
# )

# %%
total_layers = 0
for name, module in model.named_modules():
    # print(name, type(module))
    total_layers += 1
print(f"Total number of layers: {total_layers}")
# Out:
# Total number of layers: 422

# %%
total_layers = 0
for name, module in model.named_modules():
    if isinstance(module, bnb.nn.Linear4bit):
        names = name.split('.')
        layer_name = names[-1]
        if layer_name != 'lm_head':
            # print(name, type(module))
            total_layers += 1
print(f"Total number of linear layers: {total_layers}")
# Out:
# Total number of linear layers: 182

# %%
def find_linear_layers(model):
    linear_layers = set()
    for name, module in model.named_modules():
        if isinstance(module, bnb.nn.Linear4bit):
            names = name.split('.')
            layer_name = names[-1]
            if layer_name != 'lm_head':
                linear_layers.add(layer_name)
    return list(linear_layers)

lora_target_modules = find_linear_layers(model)
lora_target_modules
# Out:
# ['down_proj', 'o_proj', 'q_proj', 'gate_proj', 'v_proj', 'k_proj', 'up_proj']

# %%
lora_config = LoraConfig(
    r=16, # rank
    lora_alpha=32, # W + (alpha/rank) * (A@B)
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=lora_target_modules
)

model = get_peft_model(model, lora_config)
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Gemma2ForCausalLM(
#       (model): Gemma2Model(
#         (embed_tokens): Embedding(256000, 2304, padding_idx=0)
#         (layers): ModuleList(
#           (0-25): 26 x Gemma2DecoderLayer(
#             (self_attn): Gemma2Attention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2304, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): Gemma2RotaryEmbedding()
#             )
#             (mlp): Gemma2MLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=9216, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=9216, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=9216, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=9216, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=9216, out_features=2304, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=9216, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): PytorchGELUTanh()
#             )
#             (input_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#             (pre_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#             (post_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#             (post_attention_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#           )
#         )
#         (norm): Gemma2RMSNorm((2304,), eps=1e-06)
#       )
#       (lm_head): Linear(in_features=2304, out_features=256000, bias=False)
#     )
#   )
# )

# %%
lora_a_count = 0
lora_b_count = 0
for name, module in model.named_modules():
    if "lora" in name.lower():
        if isinstance(module, torch.nn.Linear):
            if "lora_A" in name:
                lora_a_count += 1
            elif "lora_B" in name:
                lora_b_count += 1
        # print(name, type(module))
print(f"LoRA A matrices: {lora_a_count}")
print(f"LoRA B matrices: {lora_b_count}")
print(f"Total LoRA rank pairs (A+B): {lora_a_count + lora_b_count}")
# Out:
# LoRA A matrices: 182
# LoRA B matrices: 182
# Total LoRA rank pairs (A+B): 364

# %%
training_args = TrainingArguments(
    output_dir=OUTPUT_MODEL_PATH,
    per_device_train_batch_size=10,
    gradient_accumulation_steps=1,
    num_train_epochs=10,
    learning_rate=2e-4,
    fp16=False,
    bf16=False,
    logging_strategy="epoch",
    optim="paged_adamw_32bit",
    logging_dir="./logs",
    save_strategy="epoch",
    evaluation_strategy="no",
    do_eval=False,
    group_by_length=True,
    report_to="none"
)

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=lora_config,
    dataset_text_field="qna",
    max_seq_length=512,
    tokenizer=tokenizer,
    args=training_args,
    packing=False,
)

trainer.train()

trainer.model.save_pretrained(OUTPUT_MODEL_PATH)
tokenizer.save_pretrained(OUTPUT_MODEL_PATH)

print(f"Training completed. Model saved to {OUTPUT_MODEL_PATH}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field, max_seq_length. Will not be supported from version '0.13.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:300: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:328: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/1239 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:403: UserWarning: You passed a processing_class with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `processing_class.padding_side = 'right'` to your code.
#   warnings.warn(
#     <div>
#
#       <progress value='1240' max='1240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1240/1240 10:55, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>124</td>
#       <td>1.783500</td>
#     </tr>
#     <tr>
#       <td>248</td>
#       <td>1.250900</td>
#     </tr>
#     <tr>
#       <td>372</td>
#       <td>0.871400</td>
#     </tr>
#     <tr>
#       <td>496</td>
#       <td>0.556200</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.340100</td>
#     </tr>
#     <tr>
#       <td>744</td>
#       <td>0.236900</td>
#     </tr>
#     <tr>
#       <td>868</td>
#       <td>0.189800</td>
#     </tr>
#     <tr>
#       <td>992</td>
#       <td>0.165000</td>
#     </tr>
#     <tr>
#       <td>1116</td>
#       <td>0.147800</td>
#     </tr>
#     <tr>
#       <td>1240</td>
#       <td>0.138200</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Model saved to ./gemma-2-2b-it-lol

# %%
def generate_response(prompt, model, tokenizer, temperature=0.1):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=temperature > 0,
        temperature=temperature
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=False)

test_prompt = """<start_of_turn>user
"다리우스에게 '녹서스의 실력자'라는 칭호를 준 사람은?<end_of_turn>
<start_of_turn>model
"""
response = generate_response(test_prompt, model, tokenizer)
print(response)

test_prompt = """<start_of_turn>user
"이즈리얼 부모님의 어떤 직업은?<end_of_turn>
<start_of_turn>model
"""
response = generate_response(test_prompt, model, tokenizer)
print(response)

test_prompt = """<start_of_turn>user
"신지드는 왜 자운으로 이주했나?<end_of_turn>
<start_of_turn>model
"""
response = generate_response(test_prompt, model, tokenizer)
print(response)
# Out:
# <bos><start_of_turn>user
# "다리우스에게 '녹서스의 실력자'라는 칭호를 준 사람은?<end_of_turn>
# <start_of_turn>model
# '녹서스의 실력자'라는 칭호는 스웨인이 직접 하사한 것이다.<end_of_turn>
# <bos><start_of_turn>user
# "이즈리얼 부모님의 어떤 직업은?<end_of_turn>
# <start_of_turn>model
# 이즈리얼의 부모님은 뛰어난 연금술사였고, 치료 기술을 혁신하기 위해 노력했다.<end_of_turn>
# <bos><start_of_turn>user
# "신지드는 왜 자운으로 이주했나?<end_of_turn>
# <start_of_turn>model
# 신지드는 필트오버에서 쫓겨난 후, 생명의 값어치가 크지 않은 자운에서 화학공학 관련 일을 찾기 위해 이주했다.<end_of_turn>

# %% [markdown]
# ## 3. 훈련한 모델 허깅페이스 업로드

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, pipeline
from peft import AutoPeftModelForCausalLM

# %%
NEW_MODEL_PATH = "./gemma-2-2b-it-lol"
MERGED_MODEL_PATH = "./gemma-2-2b-it-lol-merged"
BASE_MODEL = "google/gemma-2-2b-it"

# %%
model = AutoPeftModelForCausalLM.from_pretrained(
    NEW_MODEL_PATH,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
    device_map='cpu',
)

model = model.to('cpu')
merged_model = model.merge_and_unload()
merged_model.save_pretrained(MERGED_MODEL_PATH,
                             safe_serialization=True,
                             max_shard_size="2GB")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# !du -sh */
# Out:
# 2.8G	gemma-2-2b-it-lol/
# 4.9G	gemma-2-2b-it-lol-merged/
# 55M	sample_data/

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)

model = AutoModelForCausalLM.from_pretrained(
    MERGED_MODEL_PATH,
    device_map="auto",
    torch_dtype=torch.float16
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
HF_TOKEN=userdata.get('HF_WRITE_TOKEN')
REPO_NAME="gemma-2-2b-it-lol"

merged_model.push_to_hub(
    REPO_NAME,
    use_temp_dir=True,
    use_auth_token=HF_TOKEN
)

tokenizer.push_to_hub(
    REPO_NAME,
    use_temp_dir=True,
    use_auth_token=HF_TOKEN
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:894: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:894: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/34.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/star-bits/gemma-2-2b-it-lol/commit/eb58f80354a05101c05ddb8a3b573e2389bd1cfa', commit_message='Upload tokenizer', commit_description='', oid='eb58f80354a05101c05ddb8a3b573e2389bd1cfa', pr_url=None, repo_url=RepoUrl('https://huggingface.co/star-bits/gemma-2-2b-it-lol', endpoint='https://huggingface.co', repo_type='model', repo_id='star-bits/gemma-2-2b-it-lol'), pr_revision=None, pr_num=None)

# %%
pipe = pipeline(
    "text-generation",
    model="star-bits/gemma-2-2b-it-lol",
    model_kwargs={"torch_dtype": torch.bfloat16},
    device="cuda",
)

messages = [
    {"role": "user",
     "content": "신지드는 왜 자운으로 이주했나?"},
]

outputs = pipe(messages, max_new_tokens=256)
assistant_response = outputs[0]["generated_text"][-1]["content"].strip()
assistant_response
# Out:
# config.json:   0%|          | 0.00/880 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/34.4M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# '신지드는 필트오버에서 쫓겨난 후, 생명의 값어치가 크지 않은 자운에서 화학공학 관련 일을 찾기 위해 이주했다.'
